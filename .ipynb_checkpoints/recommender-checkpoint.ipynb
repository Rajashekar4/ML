# %%
'''<-------------------------------->MOVIE RECOMMENDATION SYSTEM <----------------------->'''
# Out:
# '<-------------------------------->MOVIE RECOMMENDATION SYSTEM <----------------------->'

# %%
#import pandas,numpy and seaborn
import pandas as pd
import numpy as np

# %%
# !pip install modin[ray]

# %%
#reading the credits and movies csv files
credits=pd.read_csv("D:\\ML\\tmdb_5000_credits.csv")
# # movies=pd.read_csv("D:\\ML\\tmdb_5000_movies.csv")
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4798  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4799  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4800  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4801  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4802  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4798  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4799  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4800  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4801  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4802  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4803 rows x 4 columns]

# %%
movies=pd.read_csv("C:\\Users\\orsur\\Downloads\\newdata.csv")
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... release_date  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   10/12/2009
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   19/05/2007
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   26/10/2015
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   16/07/2012
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   07/03/2012
# ...                                                 ...  ...          ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]  ...   04/09/1992
# 4799                                                 []  ...   26/12/2011
# 4800  [{"name": "Front Street Pictures", "id": 3958}...  ...   13/10/2013
# 4801                                                 []  ...   03/05/2012
# 4802  [{"name": "rusty bear entertainment", "id": 87...  ...   05/08/2005
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title vote_average  vote_count  \
# 0                                       Avatar          7.2       11800
# 1     Pirates of the Caribbean: At World's End          6.9        4500
# 2                                      Spectre          6.3        4466
# 3                        The Dark Knight Rises          7.6        9106
# 4                                  John Carter          6.1        2124
# ...                                        ...          ...         ...
# 4798                               El Mariachi          6.6         238
# 4799                                 Newlyweds          5.9           5
# 4800                 Signed, Sealed, Delivered          7.0           6
# 4801                          Shanghai Calling          5.7           7
# 4802                         My Date with Drew          6.3          16
#
#       rating
# 0       10.0
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
# ...      ...
# 4798     7.5
# 4799     7.5
# 4800     7.5
# 4801     7.5
# 4802     7.5
#
# [4803 rows x 21 columns]

# %%
#sample keywords of Avatat movie
movies[movies['original_title']=='Avatar']['keywords'].values
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... release_date  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   10/12/2009
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   19/05/2007
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   26/10/2015
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   16/07/2012
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   07/03/2012
# ...                                                 ...  ...          ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]  ...   04/09/1992
# 4799                                                 []  ...   26/12/2011
# 4800  [{"name": "Front Street Pictures", "id": 3958}...  ...   13/10/2013
# 4801                                                 []  ...   03/05/2012
# 4802  [{"name": "rusty bear entertainment", "id": 87...  ...   05/08/2005
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                          title vote_average  vote_count  \
# 0                                       Avatar          7.2       11800
# 1     Pirates of the Caribbean: At World's End          6.9        4500
# 2                                      Spectre          6.3        4466
# 3                        The Dark Knight Rises          7.6        9106
# 4                                  John Carter          6.1        2124
# ...                                        ...          ...         ...
# 4798                               El Mariachi          6.6         238
# 4799                                 Newlyweds          5.9           5
# 4800                 Signed, Sealed, Delivered          7.0           6
# 4801                          Shanghai Calling          5.7           7
# 4802                         My Date with Drew          6.3          16
#
#       rating
# 0       10.0
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
# ...      ...
# 4798     7.5
# 4799     7.5
# 4800     7.5
# 4801     7.5
# 4802     7.5
#
# [4803 rows x 21 columns]

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
# 1  300000000  [[, {, ", i, d, ", :, , 1, 2, ,, , ", n, a, m,...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [[, {, ", i, d, ", :, , 1, 4, 6, 3, ,, , ", n,...                en
# 1  [[, {, ", i, d, ", :, , 2, 7, 0, ,, , ", n, a,...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title vote_average vote_count rating  \
# 0                                    Avatar          7.2      11800   10.0
# 1  Pirates of the Caribbean: At World's End          6.9       4500   10.0
#
#   movie_id                                               cast  \
# 0    19995  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, 4, 2...
# 1      285  [[, {, ", c, a, s, t, _, i, d, ", :, , 4, ,, ,...
#
#                                                 crew
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...
# 1  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...
#
# [2 rows x 24 columns]

# %%
 #mergeing the movies and credits
movies=movies.merge(credits,on='title')

# %%
movies.merge(credits,on='title').shape
# Out:
# (4845, 30)

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [[, {, ", i, d, ", :, , 1, 4, 6, 3, ,, , ", n,...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...   title  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...  Avatar
#
#   vote_average  vote_count  rating movie_id_x  \
# 0          7.2       11800    10.0      19995
#
#                                               cast_x  \
# 0  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, 4, 2...
#
#                                               crew_x movie_id_y  \
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...      19995
#
#                                               cast_y  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                               crew_y
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 27 columns]

# %%
# requried columns:
# 1.genres
# 2.id
# 3.keywords
# 4.original title
# 5.overview
# 6.crew and cast

# %%
movies=movies[['id','genres','keywords','original_title','overview','cast_x','crew_x','rating']]

# %%
movies.head(1)
# Out:
#       id                                             genres  \
# 0  19995  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
#
#                                             keywords original_title  \
# 0  [[, {, ", i, d, ", :, , 1, 4, 6, 3, ,, , ", n,...         Avatar
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                               cast_x  \
# 0  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, 4, 2...
#
#                                               crew_x  rating
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0

# %%
movies.rename(columns = {'cast_x':'cast'}, inplace = True)
movies.rename(columns = {'crew_x':'crew'}, inplace = True)
movies.head(1)
# Out:
#       id                                             genres  \
# 0  19995  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
#
#                                             keywords original_title  \
# 0  [[, {, ", i, d, ", :, , 1, 4, 6, 3, ,, , ", n,...         Avatar
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                                 cast  \
# 0  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, 4, 2...
#
#                                                 crew  rating
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0

# %%
movies.isnull().sum()
# Out:
# id                0
# genres            0
# keywords          0
# original_title    0
# overview          3
# cast              0
# crew              0
# rating            0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# id                0
# genres            0
# keywords          0
# original_title    0
# overview          0
# cast              0
# crew              0
# rating            0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-9593f248bb6a> in <module>
# ----> 1 movies.duplicated().sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    6801         else:
#    6802             vals = (col.values for name, col in self.items() if name in subset)
# -> 6803             labels, shape = map(list, zip(*map(f, vals)))
#    6804
#    6805             ids = get_group_index(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in f(vals)
#    6769
#    6770         def f(vals) -> tuple[np.ndarray, int]:
# -> 6771             labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6772             return labels.astype("i8", copy=False), len(shape)
#    6773
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     816                 values = np.where(null_mask, na_value, values)
#     817
# --> 818         codes, uniques = factorize_array(
#     819             values,
#     820             na_sentinel=na_sentinel_arg,
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     572
#     573     table = hash_klass(size_hint or len(values))
# --> 574     uniques, codes = table.factorize(
#     575         values,
#     576         na_sentinel=na_sentinel,
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
'''keywords from genres
The ast module helps Python applications to process trees of the Python abstract syntax grammar'''
import ast
def convert(obj):
    l=[]
    for i in ast.literal_eval(obj):
        l.append(i['name'])
    return l

# %%
movies['genres']=movies['genres'].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-f70b3d855b31> in <module>
# ----> 1 movies['genres']=movies['genres'].apply(convert)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1103
#    1104         # self.f is Callable
# -> 1105         return self.apply_standard()
#    1106
#    1107     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1154             else:
#    1155                 values = obj.astype(object)._values
# -> 1156                 mapped = lib.map_infer(
#    1157                     values,
#    1158                     f,
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-42-98510bb0f407> in convert(obj)
#       4 def convert(obj):
#       5     l=[]
# ----> 6     for i in ast.literal_eval(obj):
#       7         l.append(i['name'])
#       8     return l
#
# ~\anaconda3\lib\ast.py in literal_eval(node_or_string)
#      97                     return left - right
#      98         return _convert_signed_num(node)
# ---> 99     return _convert(node_or_string)
#     100
#     101
#
# ~\anaconda3\lib\ast.py in _convert(node)
#      96                 else:
#      97                     return left - right
# ---> 98         return _convert_signed_num(node)
#      99     return _convert(node_or_string)
#     100
#
# ~\anaconda3\lib\ast.py in _convert_signed_num(node)
#      73             else:
#      74                 return - operand
# ---> 75         return _convert_num(node)
#      76     def _convert(node):
#      77         if isinstance(node, Constant):
#
# ~\anaconda3\lib\ast.py in _convert_num(node)
#      64     def _convert_num(node):
#      65         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 66             _raise_malformed_node(node)
#      67         return node.value
#      68     def _convert_signed_num(node):
#
# ~\anaconda3\lib\ast.py in _raise_malformed_node(node)
#      61         node_or_string = node_or_string.body
#      62     def _raise_malformed_node(node):
# ---> 63         raise ValueError(f'malformed node or string: {node!r}')
#      64     def _convert_num(node):
#      65         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
#
# ValueError: malformed node or string: ['[', '{', '"', 'i', 'd', '"', ':', '', '2', '8', ',', '', '"', 'n', 'a', 'm', 'e', '"', ':', '', '"', 'A', 'c', 't', 'i', 'o', 'n', '"', '}', ',', '', '{', '"', 'i', 'd', '"', ':', '', '1', '2', ',', '', '"', 'n', 'a', 'm', 'e', '"', ':', '', '"', 'A', 'd', 'v', 'e', 'n', 't', 'u', 'r', 'e', '"', '}', ',', '', '{', '"', 'i', 'd', '"', ':', '', '1', '4', ',', '', '"', 'n', 'a', 'm', 'e', '"', ':', '', '"', 'F', 'a', 'n', 't', 'a', 's', 'y', '"', '}', ',', '', '{', '"', 'i', 'd', '"', ':', '', '8', '7', '8', ',', '', '"', 'n', 'a', 'm', 'e', '"', ':', '', '"', 'S', 'c', 'i', 'e', 'n', 'c', 'e', '', 'F', 'i', 'c', 't', 'i', 'o', 'n', '"', '}', ']']

# %%
movies.head()
# Out:
#        id                                             genres  \
# 0   19995  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
# 1     285  [[, {, ", i, d, ", :, , 1, 2, ,, , ", n, a, m,...
# 2  206647  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
# 3   49026  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
# 4   49529  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
#
#                                             keywords  \
# 0  [[, {, ", i, d, ", :, , 1, 4, 6, 3, ,, , ", n,...
# 1  [[, {, ", i, d, ", :, , 2, 7, 0, ,, , ", n, a,...
# 2  [[, {, ", i, d, ", :, , 4, 7, 0, ,, , ", n, a,...
# 3  [[, {, ", i, d, ", :, , 8, 4, 9, ,, , ", n, a,...
# 4  [[, {, ", i, d, ", :, , 8, 1, 8, ,, , ", n, a,...
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                                 cast  \
# 0  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, 4, 2...
# 1  [[, {, ", c, a, s, t, _, i, d, ", :, , 4, ,, ,...
# 2  [[, {, ", c, a, s, t, _, i, d, ", :, , 1, ,, ,...
# 3  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, ,, ,...
# 4  [[, {, ", c, a, s, t, _, i, d, ", :, , 5, ,, ,...
#
#                                                 crew  rating
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0
# 1  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0
# 2  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0
# 3  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0
# 4  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...    10.0

# %%
movies['keywords']=movies['keywords'].apply(convert)

# %%
movies.head(2)

# %%
#keywords from 
def convertcast(obj):
    l=[]
    c=0
    for i in ast.literal_eval(obj):
        if c!=3:
            l.append(i['name'])
            c=c+1
        else:
            break
    return l

# %%
movies['cast']=movies['cast'].apply(convertcast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-52731ee6c1d3> in <module>
# ----> 1 movies['cast']=movies['cast'].apply(convertcast)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1103
#    1104         # self.f is Callable
# -> 1105         return self.apply_standard()
#    1106
#    1107     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1154             else:
#    1155                 values = obj.astype(object)._values
# -> 1156                 mapped = lib.map_infer(
#    1157                     values,
#    1158                     f,
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-14-4ee741da1440> in convertcast(obj)
#       3     l=[]
#       4     c=0
# ----> 5     for i in ast.literal_eval(obj):
#       6         if c!=3:
#       7             l.append(i['name'])
#
# NameError: name 'ast' is not defined

# %%
movies.head(2)

# %%
def convert_director(obj):
    l=[]
    for i in ast.literal_eval(obj):
        if(i['job']=='Director'):
            l.append(i['name'])
            break
    return l

# %%
movies['crew']=movies['crew'].apply(convert_director)

# %%
movies.head(2)

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e79d7ee73b06> in <module>
# ----> 1 movies['overview']=movies['overview'].apply(lambda x:x.split())
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1103
#    1104         # self.f is Callable
# -> 1105         return self.apply_standard()
#    1106
#    1107     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1154             else:
#    1155                 values = obj.astype(object)._values
# -> 1156                 mapped = lib.map_infer(
#    1157                     values,
#    1158                     f,
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-e79d7ee73b06> in <lambda>(x)
# ----> 1 movies['overview']=movies['overview'].apply(lambda x:x.split())
#
# AttributeError: 'float' object has no attribute 'split'

# %%
movies.head(2)

# %%
#removing the space between the names
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [[, {, ", i, d, ", :, , 2, 8, ,, , ", n, a, m,...
# 1  300000000  [[, {, ", i, d, ", :, , 1, 2, ,, , ", n, a, m,...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [[, {, ", i, d, ", :, , 1, 4, 6, 3, ,, , ", n,...                en
# 1  [[, {, ", i, d, ", :, , 2, 7, 0, ,, , ", n, a,...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title vote_average vote_count rating  \
# 0                                    Avatar          7.2      11800   10.0
# 1  Pirates of the Caribbean: At World's End          6.9       4500   10.0
#
#   movie_id                                               cast  \
# 0    19995  [[, {, ", c, a, s, t, _, i, d, ", :, , 2, 4, 2...
# 1      285  [[, {, ", c, a, s, t, _, i, d, ", :, , 4, ,, ,...
#
#                                                 crew
# 0  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...
# 1  [[, {, ", c, r, e, d, i, t, _, i, d, ", :, , "...
#
# [2 rows x 24 columns]

# %%
movies['tages']=movies['genres']+movies['keywords']+movies['overview']+movies['cast']+movies['crew']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69         _store_test_result(False)
# ---> 70     return op(a, b)
#      71
#
# TypeError: can only concatenate list (not "str") to list
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-4e1f361893be> in <module>
# ----> 1 movies['tages']=movies['genres']+movies['keywords']+movies['overview']+movies['cast']+movies['crew']
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#     100     @unpack_zerodim_and_defer("__add__")
#     101     def __add__(self, other):
# --> 102         return self._arith_method(other, operator.add)
#     103
#     104     @unpack_zerodim_and_defer("__radd__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    6257     def _arith_method(self, other, op):
#    6258         self, other = ops.align_method_SERIES(self, other)
# -> 6259         return base.IndexOpsMixin._arith_method(self, other, op)
#    6260
#    6261
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _arith_method(self, other, op)
#    1323
#    1324         with np.errstate(all="ignore"):
# -> 1325             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1326
#    1327         return self._construct_result(result, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     224         # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     225         # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 226         res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     227
#     228     return res_values
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     170             # Don't do this for comparisons, as that will handle complex numbers
#     171             #  incorrectly, see GH#32047
# --> 172             result = _masked_arith_op(left, right, op)
#     173         else:
#     174             raise
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#     108         # See GH#5284, GH#5035, GH#19448 for historical reference
#     109         if mask.any():
# --> 110             result[mask] = op(xrav[mask], yrav[mask])
#     111
#     112     else:
#
# TypeError: can only concatenate list (not "str") to list

# %%
movies.head(14)

# %%
'''required data of id,title,tages'''
new_data=movies[['id',"original_title",'tages','rating']]

# %%
new_data.head(2)

# %%
#for testing
new_data[new_data['original_title']=='Avatar']['rating']

# %%
new_data['tages']=new_data['tages'].apply(lambda x:" ".join(x))

# %%
new_data.head(2)

# %%
new_data['tages']=new_data['tages'].apply(lambda x:x.lower())

# %%
new_data.head(2)

# %%
'''T(NLTK) is a platform used for building Python programs that work with
human language data for applying in statistical natural language processing (NLP)'''

import nltk

# %%
'''the Porter stemming algorithm (or 'Porter stemmer') is a process for removing the 
commoner morphological and inflexional endings from words in English'''

from nltk.stem import PorterStemmer
stemmer=PorterStemmer()

# %%
def stem(text):
    k=[]
    for i in text.split():
        k.append(stemmer.stem(i))
    return " ".join(k)

# %%
new_data['tages']=new_data['tages'].apply(stem)

# %%
new_data.head(2)

# %%
'''Scikit-learn's CountVectorizer is used to convert a collection of text documents to a vector of term/token counts.
It also enables the ​pre-processing of text data prior to generating the vector representation. 
This functionality makes it a highly flexible feature representation module for text.'''

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
cv= CountVectorizer(max_features=5000,stop_words='english')
tv= TfidfVectorizer(max_features=5000,stop_words='english')

# %%
vectors=cv.fit_transform(new_data['tages']).toarray()
vectors2=tv.fit_transform(new_data['tages']).toarray()

# %%
tv.fit_transform(new_data['tages']).toarray().shape

# %%
cv.fit_transform(new_data['tages']).toarray().shape

# %%
#cv.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# C:\Users\orsur\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
#Compute cosine similarity between samples in X and Y
similarity=cosine_similarity(vectors)
similarity2=cosine_similarity(vectors2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-002b1559214c> in <module>
#       1 #Compute cosine similarity between samples in X and Y
# ----> 2 similarity=cosine_similarity(vectors)
#       3 similarity2=cosine_similarity(vectors2)
#
# NameError: name 'vectors' is not defined

# %%
#recommend function is used printing the top 5 related movies
def recommend(movie):
    movie_index=new_data[new_data['original_title']==movie].index[0]
    distance=similarity[movie_index]
    movie_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]
    r=[]
    m=[]
    rt=[]
    k=1
    for i in movie_list:
        r.append(int(new_data[new_data['original_title']=="{}".format(new_data.iloc[i[0]].original_title)]['rating']))
        m.append(new_data.iloc[i[0]].original_title)
        print("{} ->{}".format(k,new_data.iloc[i[0]].original_title))
        k=k+1
    for i in range(10):
        
        rt.append(r[i])
        
    s = np.array(rt)
    c=1
    j=1
    sort_index = np.argsort(s)
    print("<------------------****Top 5 rated movies among the above 10 movies****------------------>")
    for i in sort_index[::-1]:
        if(c<=5):
            print("{} ->{}".format(j,m[i]))
            c=c+1
            j=j+1

# %%
def recommend2(movie):
    movie_index=new_data[new_data['original_title']==movie].index[0]
    distance=similarity2[movie_index]
    movie_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]
    r=[]
    m=[]
    rt=[]
    k=1
    for i in movie_list:
        r.append(float(new_data[new_data['original_title']=="{}".format(new_data.iloc[i[0]].original_title)]['rating']))
        m.append(new_data.iloc[i[0]].original_title)
        print("{} ->{}".format(k,new_data.iloc[i[0]].original_title))
        k=k+1
    for i in range(10):
        
        rt.append(r[i])
    print(r)
    s = np.array(rt)
    c=1
    j=1
    tm=[]
    sort_index = np.argsort(s)
    print("<------------------****Top 5 rated movies among the above 10 movies****------------------>")
    for i in sort_index[::-1]:
        if(c<=5):
            tm.append(m[i])
#             print("{} ->{}".format(j,m[i]))
            c=c+1
            j=j+1
    print(tm)

# %% [markdown]
# ### Countvector

# %%
recommend("Quantum of Solace")

# %% [markdown]
# ### Tfidfvector

# %%
recommend2("Quantum of Solace")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e48257009f23> in <module>
# ----> 1 recommend2("Quantum of Solace")
#
# <ipython-input-1-3096d370e722> in recommend2(movie)
#       1 def recommend2(movie):
# ----> 2     movie_index=new_data[new_data['original_title']==movie].index[0]
#       3     distance=similarity2[movie_index]
#       4     movie_list=sorted(list(enumerate(distance)),reverse=True,key=lambda x:x[1])[1:11]
#       5     r=[]
#
# NameError: name 'new_data' is not defined

# %%
## Pickle in Python is primarily used in serializing and deserializing a Python object structure
import pickle

# %%
#The dump() method of the pickle module in Python, converts a Python object hierarchy into a byte stream.
#converting the data into dict
pickle.dump(new_data.to_dict(),open('movies.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-833c07a6c441> in <module>
#       1 #The dump() method of the pickle module in Python, converts a Python object hierarchy into a byte stream.
#       2 #converting the data into dict
# ----> 3 pickle.dump(new_data.to_dict(),open('movies.pkl','wb'))
#       4 pickle.dump(similarity,open('similarity.pkl','wb'))
#
# NameError: name 'new_data' is not defined

# %%
#converting the data into dict
pickle.dump(new_data.to_dict(),open('updated.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e5db3ec32110> in <module>
#       1 #converting the data into dict
# ----> 2 pickle.dump(new_data.to_dict(),open('updated.pkl','wb'))
#
# NameError: name 'new_data' is not defined

# %%
new_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c20dc32b0c88> in <module>
# ----> 1 new_data
#
# NameError: name 'new_data' is not defined
